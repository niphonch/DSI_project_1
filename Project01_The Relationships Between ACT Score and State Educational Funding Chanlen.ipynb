# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis: The Relationships Between ACT Score and State Educational Funding

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# The ACT (American College Testing) is one of the highest stake standardized tests used for high school graduation and college admission in the US. The test aims to measure educational development and readiness to pursue college-level coursework in English, Mathematics, Reading, and Science, with an additional optional writing section. (source: https://nces.ed.gov/fastfacts/display.asp?id=897). Approximately 2 million students take the test each year. However, the average test scores are dispersed widely from one state to another due to many factors. This study aims to analyze the relationships between ACT tests scores and state educational funding.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# 1. Making the grade 2019 extracted from How Fair is School Funding in Your State?  (https://edlawcenter.org/research/making-the-grade-2019.html)
#
# 2. Public Educational Spending Per Pupil extracted from U.S. Public Education Spending Statistics (https://educationdata.org/public-education-spending-statistics)
#
# 3. Pre-K - 12 Rankings extracted from Measuring how well states are preparing students for college (https://www.usnews.com/news/best-states/rankings/education/prek-12)

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
#create function to calculate mean
def mean(data):
    sum =0
    count = 0
    for i in data:
        sum +=i
        count +=1
    mean = sum/count
    return mean

# %%
data = [1,3,5,8,3,8,5]
mean(data)
# Out:
# 4.714285714285714

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
#create function to calculate standard deviation
def standard_deviation(data):
    sum =0
    count = 0
    xbar = mean(data)
    for i in data:
        sum += (i-xbar)**2
        count +=1
    sd = (sum/count)**0.5
    return sd

# %%
data = [1,3,5,8,3,8,5,20]
standard_deviation(data)
# Out:
# 5.543859215384171

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
#create function to remove % and percentage string to an actual floating point percent
def convert_percent(val):
    """
    Convert the percentage string to an actual floating point percent
    - Checking data type
    - Remove %
    - Divide by 100 to make decimal
    - Convert to float type
    """
    
    if type(val) == str:
        new_val = val.replace('%', '')
        return float(new_val) / 100
    elif type(val) == float:
        return val

# %%
#create function to remove $ and comma the convert the string number value to a float
def convert_currency(val):
    """
    Convert the string number value to a float
     - Remove $
     - Remove commas
     - Convert to float type
    """
    new_val = val.replace(',','').replace('$', '')
    return float(new_val)

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#  library to generate plots within the Jupyter notebook.
# %matplotlib inline

#this adds extra styling to the graphs
sns.set_style("whitegrid")

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
#import data files
act18= pd.read_csv('../data/act_2018.csv')
act19= pd.read_csv('../data/act_2019.csv')

# %%
#import addition data files

#Making the grade 2019 extracted from How Fair is School Funding in Your State? 
#(https://edlawcenter.org/research/making-the-grade-2019.html)
fund= pd.read_excel('../data/making_the_grade_2019.xlsx') 

#Public Educational Spending Per Pupil extracted from U.S. Public Education Spending Statistics 
#(https://educationdata.org/public-education-spending-statistics)
spend= pd.read_excel('../data/Public Educational Spending Per Pupil.xlsx')

#Pre-K - 12 Rankings extracted from Measuring how well states are preparing students for college
#(https://www.usnews.com/news/best-states/rankings/education/prek-12)
rank= pd.read_excel('../data/school ranking.xlsx')

# %% [markdown]
# #### Data Cleaning: act_2019.csv

# %%
#sample data structure 
act19.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
act19.tail()
# Out:
#             State Participation  Composite
# 47     Washington           24%       22.1
# 48  West Virginia           49%       20.8
# 49      Wisconsin          100%       20.3
# 50        Wyoming          100%       19.8
# 51       National           52%       20.7

# %%
#delete the last row  which is a national mean
act19 = act19.drop(labels=51, axis=0)

# %%
#data info
act19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          51 non-null     object
#  1   Participation  51 non-null     object
#  2   Composite      51 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
#act19.sort_values(by=['act19_composite'])

# %%
#checking missing value 
act19.isnull().sum()
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %%
#rename columns 
act19.rename(columns=
             {"State":"state","Participation":"act19_participation","Composite": "act19_composite"}, inplace=True)

# %%
#see all values to check possible strange input
act19['act19_participation'].value_counts()
# Out:
# 100%    15
# 22%      2
# 21%      2
# 49%      2
# 75%      1
# 39%      1
# 78%      1
# 12%      1
# 17%      1
# 20%      1
# 42%      1
# 96%      1
# 63%      1
# 25%      1
# 14%      1
# 82%      1
# 95%      1
# 19%      1
# 28%      1
# 38%      1
# 6%       1
# 72%      1
# 66%      1
# 29%      1
# 35%      1
# 31%      1
# 80%      1
# 54%      1
# 32%      1
# 13%      1
# 27%      1
# 23%      1
# 73%      1
# 24%      1
# Name: act19_participation, dtype: int64

# %%
#apply convert_percent function to act_19 participation and convert data type from object to float
act19['act19_participation'] = act19['act19_participation'].apply(convert_percent)

# %%
#check simple statistic
act19.describe(include='all').round(2)
# Out:
#           state  act19_participation  act19_composite
# count        51                51.00            51.00
# unique       51                  NaN              NaN
# top     Alabama                  NaN              NaN
# freq          1                  NaN              NaN
# mean        NaN                 0.59            21.46
# std         NaN                 0.35             2.19
# min         NaN                 0.06            17.90
# 25%         NaN                 0.24            19.80
# 50%         NaN                 0.54            21.10
# 75%         NaN                 1.00            23.70
# max         NaN                 1.00            25.50

# %% [markdown]
# #### Data Cleaning: act_2018.csv

# %%
#sample data structure 
act18.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
act18.tail()
# Out:
#             State Participation  Composite
# 47       Virginia           24%       23.9
# 48     Washington           24%       22.2
# 49  West Virginia           65%       20.3
# 50      Wisconsin          100%       20.5
# 51        Wyoming          100%       20.0

# %%
act18.sort_values(by=['Composite'])
# Out:
#                    State Participation  Composite
# 29                Nevada          100%       17.7
# 41        South Carolina          100%       18.3
# 25           Mississippi          100%       18.6
# 11                Hawaii           89%       18.9
# 34        North Carolina          100%       19.1
# 0                Alabama          100%       19.1
# 2                Arizona           66%       19.2
# 18             Louisiana          100%       19.2
# 37              Oklahoma          100%       19.3
# 32            New Mexico           67%       19.4
# 3               Arkansas          100%       19.4
# 43             Tennessee          100%       19.6
# 9                Florida           66%       19.9
# 51               Wyoming          100%       20.0
# 27               Montana          100%       20.0
# 26              Missouri          100%       20.0
# 28              Nebraska          100%       20.1
# 17              Kentucky          100%       20.2
# ...

# %%
#data info
act18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
#checking missing value 
act18.isnull().sum()
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %%
#rename columns 
act18.rename(columns=
             {"State":"state","Participation":"act18_participation","Composite": "act18_composite"}, inplace=True)

# %%
#apply convert_percent function to act_18 participation and convert data type from object to float
act18['act18_participation'] = act18['act18_participation'].apply(convert_percent)

# %%
#check simple statistic
act18.describe(include='all').round(2)
# Out:
#         state  act18_participation  act18_composite
# count      52                52.00            52.00
# unique     51                  NaN              NaN
# top     Maine                  NaN              NaN
# freq        2                  NaN              NaN
# mean      NaN                 0.61            21.54
# std       NaN                 0.35             2.12
# min       NaN                 0.07            17.70
# 25%       NaN                 0.27            19.98
# 50%       NaN                 0.66            21.30
# 75%       NaN                 1.00            23.72
# max       NaN                 1.00            25.60

# %% [markdown]
# #### Data Cleaning: making_the_grade_2019.xlsx

# %%
#sample data structure 
fund.head()
# Out:
#         State  Poverty Rate of School-Aged Children Funding Level  \
# 0     Alabama                                  0.23             F
# 1      Alaska                                  0.13             A
# 2     Arizona                                  0.19             F
# 3    Arkansas                                  0.21             D
# 4  California                                  0.17             D
#
#   Funding Distribution Funding Effort
# 0                    F              C
# 1                    A              B
# 2                    C              F
# 3                    C              B
# 4                    A              F

# %%
#data info
fund.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 5 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   State                                 49 non-null     object
#  1   Poverty Rate of School-Aged Children  46 non-null     float64
#  2   Funding Level                         49 non-null     object
#  3   Funding Distribution                  49 non-null     object
#  4   Funding Effort                        49 non-null     object
# dtypes: float64(1), object(4)
# memory usage: 2.0+ KB

# %%
#checking missing value 
fund.isnull().sum()
# Out:
# State                                   0
# Poverty Rate of School-Aged Children    3
# Funding Level                           0
# Funding Distribution                    0
# Funding Effort                          0
# dtype: int64

# %%
#rename columns 
fund.rename(columns=
             {"State":"state","Poverty Rate of School-Aged Children":"poverty_rate",
              "Funding Level": "funding_level","Funding Distribution":"funding_dist",
              "Funding Effort":"funding_effort"}, inplace=True)

# %%
#drop unused columns
fund.drop(['poverty_rate'], axis=1, inplace=True)

# %%
#check simple statistic
fund.describe(include='all').round(2)
# Out:
#           state funding_level funding_dist funding_effort
# count        49            49           49             49
# unique       49             5            5              5
# top     Alabama             C            C              C
# freq          1            15           20             16

# %%
#number of data in each of funding grade
fund['funding_level'].value_counts()
# Out:
# C    15
# A    12
# F    11
# D     9
# B     2
# Name: funding_level, dtype: int64

# %%
#number of data in each of funding grade
fund['funding_dist'].value_counts()
# Out:
# C    20
# F    10
# A     9
# D     6
# B     4
# Name: funding_dist, dtype: int64

# %%
#number of data in each of funding grade
fund['funding_effort'].value_counts()
# Out:
# C    16
# F    13
# A    10
# B     5
# D     5
# Name: funding_effort, dtype: int64

# %% [markdown]
# #### Data Cleaning: Public Educational Spending Per Pupil.xlsx

# %%
#sample data structure 
spend.head()
# Out:
#                   State K-12 Spending Postsecondary Spending
# 0  District of Columbia       $22,832                $27,142
# 1              New York       $24,881                $33,760
# 2           Connecticut       $21,146                $20,284
# 3               Vermont       $21,219                $31,103
# 4            New Jersey       $21,334                $32,421

# %%
#data info
spend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   51 non-null     object
#  1   K-12 Spending           51 non-null     object
#  2   Postsecondary Spending  51 non-null     object
# dtypes: object(3)
# memory usage: 1.3+ KB

# %%
#checking missing value 
spend.isnull().sum()
# Out:
# State                     0
# K-12 Spending             0
# Postsecondary Spending    0
# dtype: int64

# %%
#drop Postsecondary Spending column because it is irrelevant to high school ACT scores 
spend.drop(['Postsecondary Spending'], axis=1, inplace=True)

# %%
#rename columns 
spend.rename(columns=
             {"State":"state","K-12 Spending":"k12_spend"}, inplace=True)

# %%
#apply function to convert currency
spend['k12_spend'] = spend['k12_spend'].apply(convert_currency)

# %%
#check simple statistic
spend.describe(include='all').round(2)
# Out:
#                        state  k12_spend
# count                     51      51.00
# unique                    51        NaN
# top     District of Columbia        NaN
# freq                       1        NaN
# mean                     NaN   13468.78
# std                      NaN    4052.27
# min                      NaN    7951.00
# 25%                      NaN   10370.00
# 50%                      NaN   12266.00
# 75%                      NaN   16029.50
# max                      NaN   24881.00

# %% [markdown]
# #### Data Cleaning: school ranking.xlsx

# %%
#sample data structure 
rank.head()
# Out:
#    Overall Rank          STATE  COLLEGE READINESS  \
# 0             1     New Jersey                  3
# 1             2  Massachusetts                  4
# 2             3    Connecticut                  1
# 3             4  New Hampshire                  8
# 4             5        Vermont                 12
#
#    HIGH SCHOOL GRADUATION RATE  NAEP MATH SCORES  NAEP READING SCORES  PRE
# 0                            2                 2                    2    1
# 1                           16                 1                    1    5
# 2                           13                 9                    2    3
# 3                           11                 5                    4    7
# 4                           29                 5                    4    2

# %%
#data info
rank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Overall Rank                 50 non-null     int64
#  1   STATE                        50 non-null     object
#  2   COLLEGE READINESS            50 non-null     int64
#  3   HIGH SCHOOL GRADUATION RATE  50 non-null     int64
#  4   NAEP MATH SCORES             50 non-null     int64
#  5   NAEP READING SCORES          50 non-null     int64
#  6   PRE                          50 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.9+ KB

# %%
#checking missing value 
rank.isnull().sum()
# Out:
# Overall Rank                   0
# STATE                          0
# COLLEGE READINESS              0
# HIGH SCHOOL GRADUATION RATE    0
# NAEP MATH SCORES               0
# NAEP READING SCORES            0
# PRE                            0
# dtype: int64

# %%
#drop columns that irrelevant to this study 
rank.drop(['NAEP MATH SCORES','NAEP READING SCORES','PRE', 'HIGH SCHOOL GRADUATION RATE'], axis=1, inplace=True)

# %%
rank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Overall Rank       50 non-null     int64
#  1   STATE              50 non-null     object
#  2   COLLEGE READINESS  50 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.3+ KB

# %%
#rename columns 
rank.rename(columns=
             {"STATE":"state","Overall Rank":"overall_rank", "COLLEGE READINESS": 'college_ready'}, inplace=True)

# %%
#since small number in ranking indicates high quality property, thus converting small number to high score will make more sense in further analysis
rank['rank_score'] = 51 - rank['overall_rank']
rank['college_ready_score'] = 51 - rank['college_ready']

# %%
#drop unused columns
rank.drop(['overall_rank','college_ready'], axis=1, inplace=True)

# %% [markdown]
# #### Merge data files and create csv file

# %%
#Create act score dataframe by matching state and save as csv file
df_act = act19.merge(act18, how='left', on='state')
df_act.to_csv('act_18_19.csv')

# %%
#Create additional dataframe by matching state  about funding and ranking and save as csv file
df_add = fund.merge(spend, how='left', on='state')
df_add = df_add.merge(rank, how='left', on='state')
df_add.to_csv('additional.csv')

# %%
#Create total dataframe by matching state and save as csv file
df = df_act.merge(df_add, how='left', on='state')

# %%
#found duplicated data, must be drop
df.drop_duplicates(inplace =True)
df.to_csv('total_act_18_19.csv')

# %%
df.dropna(inplace = True)

# %%
#export dataframe as csv
df.to_csv('total_act_18_19.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49 entries, 0 to 51
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   state                49 non-null     object
#  1   act19_participation  49 non-null     float64
#  2   act19_composite      49 non-null     float64
#  3   act18_participation  49 non-null     float64
#  4   act18_composite      49 non-null     float64
#  5   funding_level        49 non-null     object
#  6   funding_dist         49 non-null     object
#  7   funding_effort       49 non-null     object
#  8   k12_spend            49 non-null     float64
#  9   rank_score           49 non-null     float64
#  10  college_ready_score  49 non-null     float64
# dtypes: float64(7), object(4)
# memory usage: 4.6+ KB

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|df/df_act/df_add|Sates in USA|
# |act19_participation|float|df/df_act| Students participation rate of 2019 ACT|
# |act19_composite|float|df/df_actT|2019 ACT composite score|
# |act18_participation|float|df/df_act| Students participation rate of 2018 ACT|
# |act18_composite|float|df/df_act|2019 ACT composite score|
# |funding_level|object|df/df_add|Funding level: determined by dividing state and local revenue by student enrollment. |
# |funding_dist |object|df/df_add|Funding distribution: do states provide more or less funding to
# districts as the poverty rate increases?|
# |funding_effort|object|df/df_add| Funding effort: measured as total state and local revenue (including capital outlay and debt service.
# excluding all federal funds) divided by the state’s gross domestic product (GDP).|
# |k12_spend |float|df/df_add| Public K-12 spending per pupil per year|
# |ranking |float|df/df_add| Overall education ranking|
# |college_ready_score|float|df/df_add|College readiness ranking|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
df.describe()
# Out:
#        act19_participation  act19_composite  act18_participation  \
# count            49.000000        49.000000            49.000000
# mean              0.587755        21.473469             0.617755
# std               0.348809         2.191725             0.342474
# min               0.060000        17.900000             0.070000
# 25%               0.240000        19.800000             0.270000
# 50%               0.540000        21.100000             0.660000
# 75%               1.000000        23.800000             1.000000
# max               1.000000        25.500000             1.000000
#
#        act18_composite     k12_spend  rank_score  college_ready_score
# count        49.000000     49.000000   49.000000            49.000000
# mean         21.506122  13223.428571   25.551020            25.183673
# std           2.100437   3881.989905   14.723933            14.554028
# min          17.700000   7951.000000    1.000000             1.000000
# ...

# %%
#calculate standard deviation using created fuction 
df_standard_deviation_dict  = {c: round(standard_deviation(df[c]),2) for c in df.columns[1:] if (df[c].dtype !='object')}
df_standard_deviation_dict
# Out:
# {'act19_participation': 0.35,
#  'act19_composite': 2.17,
#  'act18_participation': 0.34,
#  'act18_composite': 2.08,
#  'k12_spend': 3842.17,
#  'rank_score': 14.57,
#  'college_ready_score': 14.4}

# %%
#checking simple statstics
df.describe(include ='all').round(2)
# Out:
#           state  act19_participation  act19_composite  act18_participation  \
# count        49                49.00            49.00                49.00
# unique       49                  NaN              NaN                  NaN
# top     Alabama                  NaN              NaN                  NaN
# freq          1                  NaN              NaN                  NaN
# mean        NaN                 0.59            21.47                 0.62
# std         NaN                 0.35             2.19                 0.34
# min         NaN                 0.06            17.90                 0.07
# 25%         NaN                 0.24            19.80                 0.27
# 50%         NaN                 0.54            21.10                 0.66
# 75%         NaN                 1.00            23.80                 1.00
# max         NaN                 1.00            25.50                 1.00
#
# ...

# %%
# Output the correlation matrix for the total ACT dataset
df.corr().style.set_caption("Correlation Matrix for ACT test scores and funding")\
.background_gradient(cmap=sns.light_palette("red", as_cmap=True))
# Out:
# <style type="text/css">
# #T_7d12c_row0_col0, #T_7d12c_row1_col1, #T_7d12c_row2_col2, #T_7d12c_row3_col3, #T_7d12c_row4_col4, #T_7d12c_row5_col5, #T_7d12c_row6_col6 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_7d12c_row0_col1, #T_7d12c_row0_col4, #T_7d12c_row0_col5, #T_7d12c_row0_col6, #T_7d12c_row1_col0, #T_7d12c_row1_col2, #T_7d12c_row2_col1, #T_7d12c_row2_col3, #T_7d12c_row2_col4, #T_7d12c_row3_col2 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_7d12c_row0_col2, #T_7d12c_row1_col3, #T_7d12c_row2_col0, #T_7d12c_row3_col1 {
#   background-color: #ff0101;
#   color: #f1f1f1;
# }
# #T_7d12c_row0_col3, #T_7d12c_row2_col5, #T_7d12c_row3_col0 {
#   background-color: #f3efef;
#   color: #000000;
# }
# #T_7d12c_row1_col4 {
#   background-color: #fd2f2f;
#   color: #f1f1f1;
# }
# #T_7d12c_row1_col5 {
#   background-color: #fd2d2d;
#   color: #f1f1f1;
# }
# #T_7d12c_row1_col6 {
#   background-color: #fe1b1b;
#   color: #f1f1f1;
# }
# #T_7d12c_row2_col6 {
# ...

# %%
#according to the correlation matrix for the total ACT dataset
#1. ACT composite scores from 2018 and 2019 are highly correlated 
#2. ACT composite scores are moderate to high correlated to K-12 spending, school ranking, and college readiness ranking
#3. ACT composite score are highly negative correlate with test participation rate which need further analysis

# %%
#scatter plot of participation rate and ACT score 
df.plot(kind = 'scatter',figsize=(6,6), x = 'act18_participation', y = 'act18_composite')
plt.show()
df.plot(kind = 'scatter',figsize=(6,6), x = 'act19_participation', y = 'act19_composite')
plt.show()

# %%
# High negative correlation between ACT composite scores and test participation rate in both year 2018 and 2019 shows that /
# state which has lower participation rates scores better than states which has higher participation rates. 
# From the results, it can be implied that the majority of test taker from low-participation-rate states are high achievement students, while low achievement
# tend not to take the test.

# %%
#this study aims to explore the relationship between standardized test scores and state-wide educational budget spending, 
#thus, states which had participation rate below 90% are excluded from this study.

#create new 2019 dataframe by filtering out states which had participation rate below 90%
df_19filter=df.loc[df['act19_participation']>0.9]
df_18filter=df.loc[df['act18_participation']>0.9]

# %%
df_19filter.head()
# Out:
#         state  act19_participation  act19_composite  act18_participation  \
# 0     Alabama                 1.00             18.9                 1.00
# 3    Arkansas                 1.00             19.3                 1.00
# 17   Kentucky                 1.00             19.8                 1.00
# 18  Louisiana                 1.00             18.8                 1.00
# 24  Minnesota                 0.95             21.4                 0.99
#
#     act18_composite funding_level funding_dist funding_effort  k12_spend  \
# 0              19.1             F            F              C    10108.0
# 3              19.4             D            C              B    10414.0
# 17             20.2             D            C              C    11278.0
# 18             19.2             D            C              F    11917.0
# 24             21.3             C            A              C    13302.0
#
#     rank_score  college_ready_score
# 0          6.0                  7.0
# ...

# %%
#scatter plot of participation rate and ACT score excluded low-participation-rate states
df_19filter.plot(kind = 'scatter',figsize=(6,6), x = 'act19_participation', y = 'act19_composite')
plt.show()

# %%
#scatter plot of participation rate and ACT score excluded low-participation-rate states
df_18filter.plot(kind = 'scatter',figsize=(6,6), x = 'act18_participation', y = 'act18_composite')
plt.show()

# %%
# Output the correlation matrix for the total ACT dataset excluding low-participation-rate states
df_19filter.corr().style.set_caption("Correlation Matrix for ACT test scores and funding")\
.background_gradient(cmap=sns.light_palette("navy", as_cmap=True))
# Out:
# <style type="text/css">
# #T_137dd_row0_col0, #T_137dd_row1_col1, #T_137dd_row2_col2, #T_137dd_row3_col3, #T_137dd_row4_col4, #T_137dd_row5_col5, #T_137dd_row6_col6 {
#   background-color: #000080;
#   color: #f1f1f1;
# }
# #T_137dd_row0_col1, #T_137dd_row0_col3, #T_137dd_row0_col5, #T_137dd_row0_col6, #T_137dd_row1_col0, #T_137dd_row2_col4, #T_137dd_row4_col2 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# #T_137dd_row0_col2 {
#   background-color: #111188;
#   color: #f1f1f1;
# }
# #T_137dd_row0_col4, #T_137dd_row3_col2 {
#   background-color: #efeff2;
#   color: #000000;
# }
# #T_137dd_row1_col2 {
#   background-color: #eeeef1;
#   color: #000000;
# }
# #T_137dd_row1_col3, #T_137dd_row3_col1 {
#   background-color: #030381;
#   color: #f1f1f1;
# }
# #T_137dd_row1_col4 {
#   background-color: #5353a8;
#   color: #f1f1f1;
# }
# #T_137dd_row1_col5 {
#   background-color: #3d3d9d;
#   color: #f1f1f1;
# }
# #T_137dd_row1_col6 {
#   background-color: #5c5cac;
# ...

# %%
#according to the correlation matrix (excluding low-participation-rate states), 
#1. ACT composite scores from 2018 and 2019 are still highly correlated 
#2. 2019 ACT composite scores are moderately correlated with K-12 spending per pupil (0.52), school ranking (0.7), and college readiness ranking (0.5)

# %%
# Output the correlation matrix for the total ACT dataset excluding low-participation-rate states
df_18filter.corr().style.set_caption("Correlation Matrix for ACT test scores and funding")\
.background_gradient(cmap=sns.light_palette("green", as_cmap=True))
# Out:
# <style type="text/css">
# #T_0d6e7_row0_col0, #T_0d6e7_row1_col1, #T_0d6e7_row2_col2, #T_0d6e7_row3_col3, #T_0d6e7_row4_col4, #T_0d6e7_row5_col5, #T_0d6e7_row6_col6 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_0d6e7_row0_col1, #T_0d6e7_row0_col5 {
#   background-color: #cfe5cf;
#   color: #000000;
# }
# #T_0d6e7_row0_col2 {
#   background-color: #99cb99;
#   color: #000000;
# }
# #T_0d6e7_row0_col3 {
#   background-color: #94c994;
#   color: #000000;
# }
# #T_0d6e7_row0_col4 {
#   background-color: #b2d7b1;
#   color: #000000;
# }
# #T_0d6e7_row0_col6, #T_0d6e7_row2_col1, #T_0d6e7_row2_col3, #T_0d6e7_row2_col4, #T_0d6e7_row2_col5, #T_0d6e7_row4_col2, #T_0d6e7_row6_col0 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_0d6e7_row1_col0 {
#   background-color: #e0eedf;
#   color: #000000;
# }
# #T_0d6e7_row1_col2 {
#   background-color: #e0eee0;
#   color: #000000;
# }
# #T_0d6e7_row1_col3, #T_0d6e7_row3_col1 {
#   background-color: #0b850b;
# ...

# %%
#according to the correlation matrix (excluding low-participation-rate states), 
#1. ACT composite scores from 2018 and 2019 are still highly correlated 
#2. 2018 ACT composite scores are moderately correlated with K-12 spending per pupil (0.52), school ranking (0.67)
#3 2018 ACT composite scores are low correlated with college readiness ranking (0.34)

# %%
#scatter plot of K-12 spending per pupil and ACT score excluded low-participation-rate states
df_18filter.plot(kind = 'scatter',figsize=(6,6), x = 'k12_spend', y = 'act18_composite')
plt.show()

# %%
#scatter plot of K-12 spending per pupil and ACT score excluded low-participation-rate states
df_19filter.plot(kind = 'scatter',figsize=(6,6), x = 'k12_spend', y = 'act19_composite')
plt.show()

# %%
#Both K-12 spending per pupil are moderatly correlated with 2018 and 2019 ACT composite

# %%
df_18filter.sort_values(by=['k12_spend'])
# Out:
#              state  act19_participation  act19_composite  act18_participation  \
# 45            Utah                 1.00             20.3                 1.00
# 29          Nevada                 1.00             17.9                 1.00
# 37        Oklahoma                 1.00             18.9                 1.00
# 25     Mississippi                 1.00             18.4                 1.00
# 34  North Carolina                 1.00             19.0                 1.00
# 43       Tennessee                 1.00             19.4                 1.00
# 0          Alabama                 1.00             18.9                 1.00
# 3         Arkansas                 1.00             19.3                 1.00
# 41  South Carolina                 0.78             18.8                 1.00
# 17        Kentucky                 1.00             19.8                 1.00
# 26        Missouri                 0.82             20.8                 1.00
# ...

# %%
df_18filter.sort_values(by=['act18_composite'])
# Out:
#              state  act19_participation  act19_composite  act18_participation  \
# 29          Nevada                 1.00             17.9                 1.00
# 41  South Carolina                 0.78             18.8                 1.00
# 25     Mississippi                 1.00             18.4                 1.00
# 34  North Carolina                 1.00             19.0                 1.00
# 0          Alabama                 1.00             18.9                 1.00
# 18       Louisiana                 1.00             18.8                 1.00
# 37        Oklahoma                 1.00             18.9                 1.00
# 3         Arkansas                 1.00             19.3                 1.00
# 43       Tennessee                 1.00             19.4                 1.00
# 26        Missouri                 0.82             20.8                 1.00
# 27         Montana                 1.00             19.8                 1.00
# ...

# %%
df_19filter.sort_values(by=['act19_composite'])
# Out:
#              state  act19_participation  act19_composite  act18_participation  \
# 29          Nevada                 1.00             17.9                 1.00
# 25     Mississippi                 1.00             18.4                 1.00
# 18       Louisiana                 1.00             18.8                 1.00
# 37        Oklahoma                 1.00             18.9                 1.00
# 0          Alabama                 1.00             18.9                 1.00
# 34  North Carolina                 1.00             19.0                 1.00
# 3         Arkansas                 1.00             19.3                 1.00
# 43       Tennessee                 1.00             19.4                 1.00
# 17        Kentucky                 1.00             19.8                 1.00
# 27         Montana                 1.00             19.8                 1.00
# 51         Wyoming                 1.00             19.8                 1.00
# ...

# %%
#Among this group, Utah has lowest K-12 spending per pupil ($7951), while Wyoming has the highest K-12 spending per pupil (#1623)
#Among this group, Nevada has lowest 2018 composite score (17.7), while Minnesota has the highest 2018 composite score (21.3)
#Among this group, Nevada has lowest 2018 composite score (17.9), while Minnesota has the highest 2018 composite score (21.4)

# %%
#number, mean, and median of 2018 ACT composite score by grade of funding level
df_18filter.groupby(['funding_level'])['act18_composite'].agg(['count','mean','median']).round(2)
# Out:
#                count   mean  median
# funding_level
# A                  2  20.15   20.15
# C                  7  20.07   20.10
# D                  3  19.60   19.40
# F                  7  19.11   19.10

# %%
#number, mean, and median of 2019 ACT composite score by grade of funding level
df_19filter.groupby(['funding_level'])['act19_composite'].agg(['count','mean','median']).round(2)
# Out:
#                count   mean  median
# funding_level
# A                  2  19.85   19.85
# C                  5  20.30   20.00
# D                  3  19.30   19.30
# F                  7  18.97   18.90

# %%
#While the trend of data is not clear, students from states with higher grade in funding level criteria on overage tend to perform better in 2019 ACT test

# %%
#number, mean, and median of 2018 ACT composite score by grade of funding distribution
df_18filter.groupby(['funding_dist'])['act18_composite'].agg(['count','mean','median']).round(2)
# Out:
#               count   mean  median
# funding_dist
# A                 5  20.42   20.30
# B                 2  20.25   20.25
# C                 8  19.21   19.25
# F                 4  19.27   19.55

# %%
#number, mean, and median of 2019 ACT composite score by grade of funding distribution
df_19filter.groupby(['funding_dist'])['act19_composite'].agg(['count','mean','median']).round(2)
# Out:
#               count   mean  median
# funding_dist
# A                 5  20.30   20.00
# B                 2  20.05   20.05
# C                 7  19.09   19.00
# F                 3  18.90   18.90

# %%
#Students from states with higher grade in funding distribution criteria on overage tend to perform better in 2019 ACT test

# %%
#number, mean, and median of 2019 ACT composite score by grade of funding effort
df_18filter.groupby(['funding_effort'])['act18_composite'].agg(['count','mean','median']).round(2)
# Out:
#                 count   mean  median
# funding_effort
# A                   2  19.15   19.15
# B                   2  19.00   19.00
# C                   8  20.19   20.15
# D                   1  20.30   20.30
# F                   6  19.22   19.25

# %%
#number, mean, and median of 2019 ACT composite score by grade of funding effort
df_19filter.groupby(['funding_effort'])['act19_composite'].agg(['count','mean','median']).round(2)
# Out:
#                 count   mean  median
# funding_effort
# A                   1  19.80   19.80
# B                   2  18.85   18.85
# C                   7  20.03   20.00
# D                   1  19.90   19.90
# F                   6  19.05   18.95

# %%
#The difference of 2019 test scores among grade level of funding effort criteria is not significant.

# %% [markdown]
# # Visualize the Data
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
#histrogram plot of data distribution
sns.displot(df_18filter['act18_composite'], color='navy')
plt.title("Distribution of ACT 2018 composite score" , fontsize=16)
plt.show()

# %%
# 2018 ACT composite scores are spreading between 17.5 to 21.5 with the highest frequency at 20.5 (N=6)

# %%
#histrogram plot of data distribution
sns.displot(df_19filter['act19_composite'])
plt.title("Distribution of ACT 2019 composite score" , fontsize=16)
plt.show()

# %%
# 2019 ACT composite scores are spreading between 17.5 to 21.5 with the highest frequency at 20 (N=6)

# %%
#scatter plot of participation rate and ACT score 
ax= df.plot(kind = 'scatter',figsize=(8,8), x = 'act18_participation', y = 'act18_composite', 
        title='Scatter plot between 2018 participation rate and composite score', fontsize = 14 )
ax.set_xlabel("Participation rate", fontsize = 14)
ax.set_ylabel("Composite score", fontsize = 14)
plt.axvline(0.9,color ='r')
plt.show()
ax2 = df.plot(kind = 'scatter',figsize=(8,8), x = 'act19_participation', y = 'act19_composite',  
        title='Scatter plot between 2018 participation rate and composite score')
ax2.set_xlabel("Participation rate" , fontsize = 14)
ax2.set_ylabel("Composite score", fontsize = 14)
plt.axvline(0.9,color ='r')
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 8), sharey=True)
fig.suptitle(f'Scatter plot between 2018 participation rate and composite score',  fontsize=16)

axes[0].axvline(0.9,color ='r')
sns.regplot(ax=axes[0], x = 'act18_participation', y = 'act18_composite', color='navy', data=df)
axes[0].set_title('2018', fontsize=14)
axes[0].set_xlabel('Participation rate' , fontsize=14)
axes[0].set_ylabel('Composite score', fontsize = 14)


sns.regplot(ax=axes[1], x = 'act19_participation', y = 'act19_composite', color='blue', data=df)
axes[1].axvline(0.9,color ='r')
axes[1].axvline(0.9,color ='r')
axes[1].set_title('2019', fontsize=14)
axes[1].set_xlabel('Participation rate' , fontsize=14)
axes[1].set_ylabel('Composite score', fontsize = 14)
# Out:
# Text(0, 0.5, 'Composite score')

# %%
#The scatter plot and the high negative correlation between ACT composite scores and test participation rate 
#in both 2018 and 2019 shows that states which has lower participation rates scores better than states which has higher participation rates.
# From the results, it can be implied that the majority of test taker from low-participation-rate states are high achievement students, while low achievement
# tend not to take the test. 

#This study aims to explore the relationship between standardized test scores and state-wide educational budget spending, 
#thus, states which had participation rate below 90% are excluded from this study.

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 8), sharey=True)
fig.suptitle('Scatter plot between K-12 spending per pupil and ACT composite score',  fontsize=16)

sns.scatterplot(ax=axes[0],
                    x= df_18filter['k12_spend'],  #x columns
                     y = df_18filter['act18_composite'],   #y columns
                     marker = 'o', color ='navy')
axes[0].set_title('2018 ACT' , fontsize=14)
axes[0].set_xlabel('K-12 Spending per Pupil' , fontsize=14)
axes[0].set_ylabel('Composite score', fontsize = 14)

sns.scatterplot(ax=axes[1],
                    x= df_19filter['k12_spend'],  #x columns
                     y = df_19filter['act19_composite'],   #y columns
                     marker = 'o', color ='b')
axes[1].set_title('2019 ACT' , fontsize=14)
axes[1].set_xlabel('K-12 Spending per Pupil' , fontsize=14)
axes[1].set_ylabel('Composite score', fontsize = 14)
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 8), sharey=True)
fig.suptitle('Scatter plot between K-12 spending per pupil and ACT composite score',  fontsize=20)

sns.regplot(ax=axes[0],
                    x= df_18filter['k12_spend'],  #x columns
                     y = df_18filter['act18_composite'],   #y columns
                     marker = 'o', color ='navy')
axes[0].set_title('2018' , fontsize=14)
axes[0].set_xlabel('K-12 Spending per Pupil' , fontsize=18)
axes[0].set_ylabel('Composite score', fontsize = 18)

sns.regplot(ax=axes[1],
                    x= df_19filter['k12_spend'],  #x columns
                     y = df_19filter['act19_composite'],   #y columns
                     marker = 'o', color ='b')
axes[1].set_title('2019' , fontsize=14)
axes[1].set_xlabel('K-12 Spending per Pupil' , fontsize=18)
axes[1].set_ylabel('Composite score', fontsize = 18)
plt.show()

# %%
#Both K-12 spending per pupil are moderatly correlated with 2018 and 2019 ACT composite (0.5)

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 6), sharey=True)
fig.suptitle('Boxplot of ACT composite score by Funding Level grade',  fontsize=20)

sns.boxplot(ax=axes[0], x='funding_level', 
            y='act18_composite', 
            order=['A', 'B', 'C', 'D', 'F'],
            data=df_18filter)
axes[0].set_title('2018', fontsize=18)
axes[0].set_xlabel('Funding Level' , fontsize=18)
axes[0].set_ylabel('Composite score', fontsize = 18)

sns.boxplot(ax=axes[1], x='funding_level', 
            y='act19_composite',
            order=['A', 'B', 'C', 'D', 'F'],
            data=df_19filter)
axes[1].set_title('2019', fontsize=18)
axes[1].set_xlabel('Funding Level' , fontsize=18)
axes[1].set_ylabel('Composite score', fontsize = 18)

plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 6), sharey=True)
fig.suptitle('Boxplot of ACT composite score by Funding distribution grade', fontsize=20)

sns.boxplot(ax=axes[0], x='funding_dist', 
            y='act18_composite', 
            order=['A', 'B', 'C', 'D', 'F'],
            data=df_18filter)
axes[0].set_title('2018', fontsize=18)
axes[0].set_xlabel('Funding Distribution' , fontsize=18)
axes[0].set_ylabel('Composite score', fontsize = 18)

sns.boxplot(ax=axes[1], x='funding_dist', 
            y='act19_composite', 
            order=['A', 'B', 'C', 'D', 'F'],
            data=df_19filter)
axes[1].set_title('2019', fontsize=18)
axes[1].set_xlabel('Funding Distribution' , fontsize=18)
axes[1].set_ylabel('Composite score', fontsize = 18)
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 6), sharey=True)
fig.suptitle('Boxplot of ACT composite score by Funding effort grade', fontsize=20)

sns.boxplot(ax=axes[0], x='funding_effort', 
            y='act18_composite', 
            order=['A', 'B', 'C', 'D', 'F'],
            data=df_18filter)
axes[0].set_title('2018', fontsize=18)
axes[0].set_xlabel('Funding Effort' , fontsize=18)
axes[0].set_ylabel('Composite score', fontsize = 18)

sns.boxplot(ax=axes[1], x='funding_effort', 
            y='act19_composite',
            order=['A', 'B', 'C', 'D', 'F'],
            data=df_19filter)
axes[1].set_title('2019', fontsize=18)
axes[1].set_xlabel('Funding Effort' , fontsize=18)
axes[1].set_ylabel('Composite score', fontsize = 18)

plt.show()

# %%
#While the trend of data is not clear, students from states with higher grade in funding level criteria on overage tend to perform better in 2019 ACT test
#Students from states with higher grade in funding distribution criteria on overage tend to perform better in 2019 ACT test
#The difference of 2019 test scores among grade level of funding effort criteria is not significant.

# %%
# Output the correlation matrix for the total ACT dataset excluding low-participation-rate states
df_18filter.corr().style.set_caption("Correlation Matrix for ACT test scores and funding")\
.background_gradient(cmap=sns.light_palette("navy", as_cmap=True))
# Out:
# <style type="text/css">
# #T_96462_row0_col0, #T_96462_row1_col1, #T_96462_row2_col2, #T_96462_row3_col3, #T_96462_row4_col4, #T_96462_row5_col5, #T_96462_row6_col6 {
#   background-color: #000080;
#   color: #f1f1f1;
# }
# #T_96462_row0_col1, #T_96462_row0_col5 {
#   background-color: #d4d4e5;
#   color: #000000;
# }
# #T_96462_row0_col2 {
#   background-color: #9d9dcb;
#   color: #f1f1f1;
# }
# #T_96462_row0_col3 {
#   background-color: #9898c8;
#   color: #f1f1f1;
# }
# #T_96462_row0_col4 {
#   background-color: #b6b6d7;
#   color: #000000;
# }
# #T_96462_row0_col6, #T_96462_row2_col1, #T_96462_row2_col3, #T_96462_row2_col4, #T_96462_row2_col5, #T_96462_row4_col2, #T_96462_row6_col0 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# #T_96462_row1_col0 {
#   background-color: #e5e5ed;
#   color: #000000;
# }
# #T_96462_row1_col2 {
#   background-color: #e6e6ee;
#   color: #000000;
# }
# #T_96462_row1_col3, #T_96462_row3_col1 {
#   background-color: #0b0b85;
# ...

# %%
# Visualize the correlation matrix via Seaborn heatmap...

plt.figure(figsize = (8,8))
sns.heatmap(df_18filter.corr(), annot = True);

# %%
# Output the correlation matrix for the total ACT dataset excluding low-participation-rate states
df_19filter.corr().style.set_caption("Correlation Matrix for ACT test scores and funding")\
.background_gradient(cmap=sns.light_palette("navy", as_cmap=True))
# Out:
# <style type="text/css">
# #T_4ef5c_row0_col0, #T_4ef5c_row1_col1, #T_4ef5c_row2_col2, #T_4ef5c_row3_col3, #T_4ef5c_row4_col4, #T_4ef5c_row5_col5, #T_4ef5c_row6_col6 {
#   background-color: #000080;
#   color: #f1f1f1;
# }
# #T_4ef5c_row0_col1, #T_4ef5c_row0_col3, #T_4ef5c_row0_col5, #T_4ef5c_row0_col6, #T_4ef5c_row1_col0, #T_4ef5c_row2_col4, #T_4ef5c_row4_col2 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# #T_4ef5c_row0_col2 {
#   background-color: #111188;
#   color: #f1f1f1;
# }
# #T_4ef5c_row0_col4, #T_4ef5c_row3_col2 {
#   background-color: #efeff2;
#   color: #000000;
# }
# #T_4ef5c_row1_col2 {
#   background-color: #eeeef1;
#   color: #000000;
# }
# #T_4ef5c_row1_col3, #T_4ef5c_row3_col1 {
#   background-color: #030381;
#   color: #f1f1f1;
# }
# #T_4ef5c_row1_col4 {
#   background-color: #5353a8;
#   color: #f1f1f1;
# }
# #T_4ef5c_row1_col5 {
#   background-color: #3d3d9d;
#   color: #f1f1f1;
# }
# #T_4ef5c_row1_col6 {
#   background-color: #5c5cac;
# ...

# %%
plt.figure(figsize = (8,8))
sns.heatmap(df_19filter.corr(), annot = True);

# %%
#according to the correlation matrix (excluding low-participation-rate states), 
#1. ACT composite scores from 2018 and 2019 are still highly correlated 
#2. 2019 ACT composite scores are moderately correlated with K-12 spending per pupil (0.52), school ranking (0.7), and college readiness ranking (0.5)
#3. 2018 ACT composite scores are moderately correlated with K-12 spending per pupil (0.52), school ranking (0.67)
#4. 2018 ACT composite scores are low correlated with college readiness ranking (0.34)

# %% [markdown]
# # Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# The aims of this study is to analyze the relationships between ACT tests scores and state educational funding. The results show that the public K-12 spending per pupil are moderately correlated with both 2018 and 2019 ACT composite scores, meaning the higher States allocate their budget to support K-12 education, the higher average ACT scores. Furthermore, the States which have higher grade in funding distribution have higher average ACT scores, while the other aspects of funding (funding level and funding effort) tend to produce relatively small to no difference in average ACT scores.
# Thus, we recommend the States and school administrators who are responsible for school budget planning to
# 1.	Increase budget spending per pupil.
# 2.	Strategically allocate spending to help low-achieving students and students who are in poverty.
#
# The results also show that Utha has the lowest public K-12 spending per pupil among the group, however, it's average ACT scores are relatively high. While Minesota has relatively high public K-12 spending per pupil, however, it's average ACT scores are the highest among the group. This highlights the needs of a more in-depth analysis of Utha and Minesota educational management and funding in the future.

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
